# %%
# basic prgrm--------
name = input("Enter your name: ");
age = input("Enter your age: ");

print(f"My name is {name} and im {age} years old. Thanks")

# even or odd--------
# num = int(input("Enter a number: "));
# if num % 2 == 0:
#     print("even");
# else :
#     print("odd");
# Out:
# My name is Jesse and im 27 years old. Thanks
