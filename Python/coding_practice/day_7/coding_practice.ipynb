# %% [markdown]
# # 1. Write a Python program to check whether a string contains only digits.

# %%
def checkDigits(text):
    for i in text:
        if not i.isdigit():
            return False;
    return f"contains only digits";
    
print(checkDigits('12345'));
# Out:
# contains only digits

# %% [markdown]
# # 2. Write a Python program to find the longest word in a string.

# %%
def findLongestWord(text):
    words = text.split();
    max = '';
    
    for word in words:
        if len(word) > len(max):
            max = word;

    return max;            
print(findLongestWord('hello guys wassup'));
# Out:
# wassup

# %% [markdown]
# # 3. Write a Python program to capitalize the first and last character of each word in a string.

# %%
def fnCaplitalize(text):
    words = text.split();
    result = [];
    
    for word in words:
        if len(word) > 1:
            new_word = word[0].upper() + word[1:-1] + word[-1].upper();
            result.append(new_word);
        else:
            result.append(word.upper())    
    return ' '.join(result);
    
print(fnCaplitalize('this is best question'));
# Out:
# ThiS IS BesT QuestioN

# %% [markdown]
# # 4. Draw a right-angled triangle pattern using stars.

# %%
# *
# * *
# * * *
# * * * *
# * * * * *

def right_triangle(n):
    for i in range(1,n+1):
        print('* ' * i);
        
right_triangle(5);
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %% [markdown]
# # 5. Draw an inverted right-angled triangle pattern.

# %%
def inverted_triangle(n):
    for i in range(n, 0, -1):
        print('* ' * i);
    
inverted_triangle(5);
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *
